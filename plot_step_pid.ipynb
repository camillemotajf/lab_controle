# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dados_pid = pd.read_csv("dados_pid.csv")
display(dados_pid)
# Out:
#     rpm_controlado
# 0           1981.8
# 1           1977.9
# 2           1977.3
# 3           1968.3
# 4           1983.0
# 5           1969.5
# 6           1983.0
# 7           1975.2
# 8           1982.7
# 9           1990.5
# 10          1953.9
# 11          1987.8
# 12          1992.3
# 13          1976.4
# 14          1986.6
# 15          1983.0
# 16          1974.9
# 17          1978.8
# 18          1982.1
# 19          1970.7
# 20          1981.5
# 21          1981.2
# 22          1982.1
# 23          1994.4
# 24          1974.3
# 25          1968.6
# 26          1975.2
# 27          1968.9
# 28          1975.8
# 29          1953.3
# 30          1974.0
# 31          1980.0
# 32          1982.7
# 33          1993.2
# 34          1985.1
# 35          1977.0
# 36          1981.2
# 37          1981.2
# 38          1972.2
# 39          1979.1
# 40          1971.9
# 41          1965.9

# %%
plt.figure(figsize=(10,5))
plt.plot(dados_pid)
plt.show()
