# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.signal import find_peaks

# %%
data_10_out = pd.read_csv('dados_rpm_10hz.csv')

# %%
amostras = data_10_out['rpm']
num_amostras = len(amostras)

# %%
# Encontrar os índices dos picos positivos da senoide
peaks, _ = find_peaks(amostras)
# Calcular o número médio de amostras entre os picos
num_amostras_por_ciclo = np.mean(np.diff(peaks))


Fs = num_amostras_por_ciclo * 1  # Frequência da senoide é 1 Hz
print(f"Frequência de amostragem estimada: {Fs} Hz")

# Gerar o vetor de tempo
t = np.arange(0, num_amostras / Fs, 1 / Fs)
t = pd.DataFrame(t)
# Out:
# Frequência de amostragem estimada: 2.9837916063675833 Hz

# %%
plt.figure(figsize=(10,5))
# plt.plot(data['tempo'].iloc[5:100], data['tensao'].iloc[5:100], label= 'Senoide Ts = 1ms')
plt.plot(t.iloc[300:1400], data_10_in['tensao'].iloc[300:1400])
plt.xlabel('Tempo (s)')
plt.ylabel('Tensão PWM')
plt.title('Tensão de saída em 10 Hz')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 plt.figure(figsize=(10,5))
#       2 # plt.plot(data['tempo'].iloc[5:100], data['tensao'].iloc[5:100], label= 'Senoide Ts = 1ms')
# ----> 3 plt.plot(t.iloc[300:1400], data_10_in['tensao'].iloc[300:1400])
#       4 plt.xlabel('Tempo (s)')
#       5 plt.ylabel('Tensão PWM')
#
# NameError: name 'data_10_in' is not defined

# %%
plt.figure(figsize=(10,5))
# plt.plot(data['tempo'].iloc[5:100], data['tensao'].iloc[5:100], label= 'Senoide Ts = 1ms')
plt.plot(data_10_out['rpm'].iloc[300:1400])
plt.xlabel('Tempo (s)')
plt.ylabel('Velocidade RPM')
plt.title('Velocidade do Eixo em 100 Hz')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(t, data_10_out['rpm'])
plt.xlabel('Tempo (s)')
plt.ylabel('Tensão PWM')
plt.title('Tensão de saída em 1 Hz')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(data_01_out['tensao'])
plt.xlabel('Tempo (s)')
plt.ylabel('Tensão PWM')
plt.title('Tensão de saída em 0.1 Hz')
plt.grid()
plt.show()
