# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('dados_senoide_1ms.csv')
data2 = pd.read_csv('dados_senoide_10ms.csv')
data3 = pd.read_csv('dados_senoide_100ms.csv')
data4 = pd.read_csv('dados_senoide_100us.csv')

data = pd.read_csv('dados_senoide_tensao.csv')

# data['Tempo'] = [float(x)*10**-6 for x in data['Tempo']]

# %%
indices1 = np.arange(len(data1['tempo']))
indices1 = np.arange(len(data2['tempo']))
indices1 = np.arange(len(data3['tempo']))

# %%
plt.figure(figsize=(15,10))
plt.plot(data1['tempo'].iloc[5:100], data1['tensao'].iloc[5:100], label= 'Senoide Ts = 1ms')
plt.plot(data2['tempo'].iloc[5:100], data2['tensao'].iloc[5:100], label='Senoide Ts = 10ms')
plt.plot(data3['tempo'].iloc[5:100], data3['tensao'].iloc[5:100], label='Senoide Ts = 100s')
plt.plot(data4['tempo'].iloc[5:100], data4['tensao'].iloc[5:100], label='Senoide Ts = 100s')
plt.grid()

plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(data['tempo'], data['tensao'], label= 'Senoide Ts = 1ms')
# plt.plot(data['tempo'].iloc[5:100], data['tensao'].iloc[5:100], label= 'Senoide Ts = 1ms')
plt.grid()
plt.show()

plt.show()
