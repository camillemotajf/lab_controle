# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_10_out = pd.read_csv('dados_senoide_10hz.csv')
data_100_out = pd.read_csv('dados_senoide_100hz.csv')
data_1_out = pd.read_csv('dados_senoide_1hz.csv')
data_01_out = pd.read_csv('dados_senoide_0.1hz.csv')

# data_rpm = pd.read_csv('dados_rpm_100hz.csv')
# data['Tempo'] = [float(x)*10**-6 for x in data['Tempo']]

# %%
data_10_in = pd.read_csv('dados_rpm_10hz.csv')
data_100_in = pd.read_csv('dados_rpm_100hz.csv')
data_01_in = pd.read_csv('dados_rpm_0.1hz.csv')

# %%
plt.figure(figsize=(10,5))
# plt.plot(data['tempo'].iloc[5:100], data['tensao'].iloc[5:100], label= 'Senoide Ts = 1ms')
plt.plot(data_10_out['tensao'].iloc[300:1400])
plt.xlabel('Tempo (s)')
plt.ylabel('Tensão PWM')
plt.title('Tensão de saída em 10 Hz')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
# plt.plot(data['tempo'].iloc[5:100], data['tensao'].iloc[5:100], label= 'Senoide Ts = 1ms')
plt.plot(data_100_in['rpm'].iloc[200:500])
plt.xlabel('Tempo (s)')
plt.ylabel('Velocidade RPM')
plt.title('Velocidade do Eixo em 100 Hz')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(data_100_out['tensao'].iloc[:200])
plt.xlabel('Tempo (s)')
plt.ylabel('Tensão PWM')
plt.title('Tensão de saída em 100 Hz')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(data_1_out['tensao'])
plt.xlabel('Tempo (s)')
plt.ylabel('Tensão PWM')
plt.title('Tensão de saída em 1 Hz')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(data_01_out['tensao'])
plt.xlabel('Tempo (s)')
plt.ylabel('Tensão PWM')
plt.title('Tensão de saída em 0.1 Hz')
plt.grid()
plt.show()
